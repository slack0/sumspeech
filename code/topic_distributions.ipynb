# %%
# %run ./main.py
# Out:
# 'Grabbing URL: http://www.americanrhetoric.com/speeches/convention2004/barackobama2004dnc.htm'
# 'Grabbing URL: http://www.americanrhetoric.com/speeches/barackobama/barackobamasenatespeechonohioelectoralvotes.htm'
# 'Grabbing URL: http://www.americanrhetoric.com/speeches/barackobamaknoxcollege.htm'
# 'Grabbing URL: http://www.americanrhetoric.com/speeches/barackobama/barackobamasenatefloorspeechpatriotact.htm'
# 'Grabbing URL: http://www.americanrhetoric.com/speeches/barackobama/barackobamasenatespeechoncorettascottkingpassing.htm'
# 'Grabbing URL: http://www.americanrhetoric.com/speeches/barackobama/barackobamasenatespeechonvotingrightsactrenewal.htm'
# 'Grabbing URL: http://www.cfr.org/us-election-2008/obamas-speech-woodrow-wilson-center/p13974'
# 'Grabbing URL: http://www.americanrhetoric.com/speeches/barackobamaexploratory.htm'
# 'Grabbing URL: http://www.americanrhetoric.com/speeches/barackobamacandidacyforpresident.htm'
# ...

# %%
doc2topic.shape
# Out:
# (181, 10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.figure(figsize=(10,6))

# %%
plt.barh?

# %%
plt.plot(doc2topic[0])

# %%
plt.plot(doc2topic[1])

# %%
plt.plot(doc2topic[2])

# %%
plt.plot(doc2topic[3])

# %%
plt.plot(doc2topic[4])

# %%
type(doc2topic)
# Out:
# numpy.ndarray

# %%
import pandas as pd

# %%
df = pd.DataFrame(doc2topic, columns=['TopicA', 'TopicB', 'TopicC', 'TopicD','TopicE', 'TopicF', 'TopicG', 'TopicH', 'TopicI', 'TopicJ'])

# %%
import matplotlib
matplotlib.style.use('ggplot')

# %%
df.plot.bar()

# %%
ndf = df[0:6]

# %%
ndf
# Out:
#      TopicA    TopicB    TopicC    TopicD    TopicE    TopicF    TopicG  \
# 0  0.005862  0.000000  0.002367  0.000000  0.008191  0.002949  0.106613
# 1  0.000000  0.013396  0.002052  0.000421  0.000000  0.024981  0.033715
# 2  0.017400  0.012224  0.006948  0.000000  0.000000  0.008900  0.091544
# 3  0.002504  0.013060  0.006200  0.007465  0.003388  0.031141  0.010817
# 4  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.066343
# 5  0.000000  0.007110  0.002595  0.008138  0.000000  0.016242  0.045753
#
#      TopicH    TopicI    TopicJ
# 0  0.000000  0.004254  0.000000
# 1  0.000000  0.000000  0.000000
# 2  0.005480  0.003332  0.006561
# 3  0.000967  0.000000  0.001437
# 4  0.000000  0.000000  0.000000
# 5  0.002930  0.000000  0.000000

# %%
ndf.plot.bar(figsize=(20,10),fontsize=15)
